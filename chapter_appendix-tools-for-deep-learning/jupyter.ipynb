# %% [markdown]
# <a href="https://colab.research.google.com/github/prachip4013-ctrl/Prachii/blob/main/chapter_appendix-tools-for-deep-learning/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assignment 2
# Taking two numbers
a = 15
b = 5
sum = a + b
print("sum =", sum)

# Output: sum = 20
# Declare variables
a = 2         # integer
b = 1.3       # float
c = "Hello"   # string

# Display variables
print("value of a :", a)
print("value of b :", b)
print("value of c :", c)

# Display types of variables
print("Type of a :", type(a))
print("Type of b :", type(b))
print("Type of c :", type(c))
# Declare variables
a = 10    # integer
b = 6.7   # float

# Type casting
x = float(a)  # int to float
y = int(b)    # float to int

# Display result
print("Original value of a :", a)
print("Type :", type(a))

print("After casting a to float :", x)
print("Type :", type(x))
# Declare variables
a = 10
b = 5

# Logical AND
print("a > 5 and b > 2 :", a > 5 and b > 2)

# Logical OR
print("a > 15 or b > 2 :", a > 15 or b > 2)
# Out:
# sum = 20
# value of a : 2
# value of b : 1.3
# value of c : Hello
# Type of a : <class 'int'>
# Type of b : <class 'float'>
# Type of c : <class 'str'>
# Original value of a : 10
# Type : <class 'int'>
# After casting a to float : 10.0
# Type : <class 'float'>
# a > 5 and b > 2 : True
# a > 15 or b > 2 : True
